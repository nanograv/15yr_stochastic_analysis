# %%
import pickle
import bz2

with open('./15yr_pint.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
psrs = []
for psr in data:
    with bz2.BZ2File('./jar/' + psr.name + '.pkl', 'rb') as f:
        psr2 = pickle.load(f)
        psrs.append(psr2)
